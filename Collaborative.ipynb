# %%
# Used to read the Parquet data
import pyarrow.parquet as parquet
# Used to train the baseline model
from sklearn.linear_model import LogisticRegression

# Where the downloaded data are
input_path = './'
# Where to store results
output_path = './'

# %%
# Read a single day to train model on as Pandas dataframe
data = parquet.read_table('/home/protus/Documents/DATASETS/ML_Boot_camp/Colaborative filtering/train/date=2018-02-07').to_pandas()
data.head(10)
# Out:
#    instanceId_userId instanceId_objectType  instanceId_objectId  audit_pos  \
# 0                173                 Photo              3187174          8
# 1                392                  Post             25653289          2
# 2                482                  Post             28597489          0
# 3                677                  Post             24734385          2
# 4                803                  Post             16701484         10
# 5               1085                  Post             16066491         33
# 6               1085                  Post             16707808          3
# 7               1325                  Post             26751805          7
# 8               1418                  Post             15652104          2
# 9               1730                  Post             30453811          6
#
#   audit_clientType  audit_timestamp  audit_timePassed  audit_resourceType  \
# 0              MOB    1518027320610           2477188                   3
# 1              API    1517999642698          14061930                   8
# 2              API    1518017550599         158887656                  14
# 3              API    1518024150740          30873010                   8
# 4              WEB    1518033115927            185743                   8
# 5              API    1518009042767            623953                   8
# 6              API    1518009761702            719045                   8
# 7              MOB    1518016444325            643362                   8
# 8              API    1518018077467          78597021                   8
# 9              API    1518030671680           1007830                   8
#
#    metadata_ownerId   metadata_ownerType  ...  \
# 0             80461           GROUP_OPEN  ...
# 1              2398  GROUP_OPEN_OFFICIAL  ...
# 2             33222  GROUP_OPEN_OFFICIAL  ...
# 3             65142  GROUP_OPEN_OFFICIAL  ...
# 4              7473  GROUP_OPEN_OFFICIAL  ...
# 5             13015  GROUP_OPEN_OFFICIAL  ...
# 6              7473  GROUP_OPEN_OFFICIAL  ...
# 7             80709  GROUP_OPEN_OFFICIAL  ...
# 8             68049  GROUP_OPEN_OFFICIAL  ...
# 9             30935  GROUP_OPEN_OFFICIAL  ...
#
#    auditweights_userOwner_PHOTO_VIEW  auditweights_userOwner_TEXT  \
# 0                                NaN                          NaN
# 1                                NaN                          NaN
# 2                                NaN                          NaN
# 3                                NaN                          NaN
# 4                                NaN                          NaN
# 5                                NaN                     0.999089
# 6                                NaN                          NaN
# 7                                NaN                          NaN
# 8                                NaN                          NaN
# 9                                NaN                          NaN
#
#    auditweights_userOwner_UNKNOWN  auditweights_userOwner_USER_FEED_REMOVE  \
# 0                             NaN                                      NaN
# 1                             NaN                                      NaN
# 2                             NaN                                      NaN
# 3                             NaN                                      NaN
# 4                             NaN                                      NaN
# 5                             NaN                                      NaN
# 6                             NaN                                      NaN
# 7                             NaN                                      NaN
# 8                             NaN                                      NaN
# 9                             NaN                                      NaN
#
#    auditweights_userOwner_USER_PROFILE_VIEW  auditweights_userOwner_VIDEO  \
# 0                                       NaN                           NaN
# 1                                       NaN                           NaN
# 2                                       NaN                           NaN
# 3                                       NaN                           NaN
# 4                                       NaN                           NaN
# 5                                       NaN                           NaN
# 6                                       NaN                           NaN
# 7                                       NaN                           NaN
# 8                                       NaN                           NaN
# 9                                       NaN                           NaN
#
#    auditweights_x_ActorsRelations  auditweights_svd  \
# 0                             NaN          0.476469
# 1                             NaN          0.705798
# 2                           512.0          0.864366
# 3                             NaN          0.705589
# 4                             NaN          0.885362
# 5                             NaN          0.771723
# 6                             NaN          0.861918
# 7                         16384.0          0.662312
# 8                             NaN          0.663812
# 9                             NaN          0.945954
#
#                                              ImageId  \
# 0                                               None
# 1                 [aa201cf14b5a63a9e127ad1e5332e3fa]
# 2                                               None
# 3                 [6c0c1b7d30609dae56c769d7cfc34328]
# 4                 [16046b50cfe254602c6e28980ea3d351]
# 5                 [72bfd952a933e5e9523fa07242a7e095]
# 6                 [5ee45ab3bf9582149b5f90d32bb22294]
# 7  [65947835aec9293639a7a4b78b3eed53, 1177aecca38...
# 8                 [4ddf657df70b115e329ee2cfabc51664]
# 9                 [a871ded97834db2393f40800f7354d07]
#
#   auditweights_likersSvd_hyper
# 0                          NaN
# 1                          NaN
# 2                     0.533798
# 3                     0.904450
# 4                          NaN
# 5                          NaN
# 6                          NaN
# 7                     0.651852
# 8                     0.838941
# 9                          NaN
#
# [10 rows x 106 columns]

# %%
# Construct the label (liked objects)
y = data['feedback'].apply(lambda x: 1.0 if("Liked" in x) else 0.0).values

# Extract the most interesting features
X = data[[
        'auditweights_svd_prelaunch', 
        'auditweights_ctr_high', 
        'auditweights_ctr_gender', 
        'auditweights_friendLikes']].fillna(0.0).values

# %%
# Fit the model and check the weights
model = LogisticRegression(random_state=0, solver='lbfgs').fit(X, y)
model.coef_
# Out:
# array([[ 4.6212144 ,  2.69850023, -0.19539506,  0.12107017]])

# %%
# Read the test data
test = parquet.read_table(input_path + '/collabTest').to_pandas()
test.head(10)
# Out:
# /Users/dmitriybugaichenko/anaconda/envs/python37/lib/python3.7/site-packages/pyarrow/pandas_compat.py:752: FutureWarning: .labels was deprecated in version 0.24.0. Use .codes instead.
#   labels, = index.labels
#    instanceId_userId instanceId_objectType  instanceId_objectId  audit_pos  \
# 0                681                  Post             35119221          7
# 1                681                  Post             35151632         32
# 2                681                  Post             20314212          9
# 3               1428                  Post             27968107          3
# 4               1428                  Post             24530710          2
# 5               2064                  Post             39107414          2
# 6               2064                  Post             36600601          2
# 7               2388                  Post             23246730          1
# 8               2388                  Post             30828036          2
# 9               2706                  Post             38122236          7
#
#   audit_clientType  audit_timestamp  audit_timePassed audit_experiment  \
# 0              API    1521813396697            360522    XPRM-5386_G10
# 1              API    1521904815253           3314178    XPRM-5386_G10
# 2              API    1522394611865            803588    XPRM-5386_G10
# 3              API    1522205864350          27994833     XPRM-5386_G4
# 4              API    1522515569257            753104     XPRM-5386_G4
# 5              API    1521991610627           2558537     XPRM-5386_G9
# 6              API    1521993892399            708736     XPRM-5386_G9
# 7              MOB    1522304987799          75927584     XPRM-5386_G5
# 8              MOB    1522355681967            203214     XPRM-5386_G5
# 9              MOB    1521923473536          23161418     XPRM-5386_G9
#
#    audit_resourceType  metadata_ownerId  ...  \
# 0                   8             14952  ...
# 1                   8              9182  ...
# 2                   8             16395  ...
# 3                   8             15993  ...
# 4                   8             53860  ...
# 5                   8             61558  ...
# 6                   8             19761  ...
# 7                   8             68570  ...
# 8                   8             78974  ...
# 9                   8             81707  ...
#
#   auditweights_userOwner_USER_INTERNAL_UNLIKE  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# 5                                         NaN
# 6                                         NaN
# 7                                         NaN
# 8                                         NaN
# 9                                         NaN
#
#    auditweights_userOwner_USER_PRESENT_SEND  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# 5                                       NaN
# 6                                       NaN
# 7                                       NaN
# 8                                       NaN
# 9                                       NaN
#
#    auditweights_userOwner_USER_PROFILE_VIEW  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# 5                                       NaN
# 6                                       NaN
# 7                                       NaN
# 8                                       NaN
# 9                                       NaN
#
#    auditweights_userOwner_USER_SEND_MESSAGE  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# 5                                       NaN
# 6                                       NaN
# 7                                       NaN
# 8                                       NaN
# 9                                       NaN
#
#    auditweights_userOwner_USER_STATUS_COMMENT_CREATE  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#    auditweights_userOwner_VIDEO  auditweights_userOwner_VOTE_POLL  \
# 0                           NaN                               NaN
# 1                           NaN                               NaN
# 2                           NaN                               NaN
# 3                           NaN                               NaN
# 4                           NaN                               NaN
# 5                           NaN                               NaN
# 6                           NaN                               NaN
# 7                           NaN                               NaN
# 8                           NaN                               NaN
# 9                           NaN                               NaN
#
#    auditweights_x_ActorsRelations  auditweights_likersSvd_spark_hyper  \
# 0                             NaN                            0.927496
# 1                             NaN                                 NaN
# 2                           512.0                                 NaN
# 3                           512.0                                 NaN
# 4                            64.0                                 NaN
# 5                             NaN                                 NaN
# 6                             NaN                                 NaN
# 7                             NaN                                 NaN
# 8                             NaN                                 NaN
# 9                             NaN                                 NaN
#
#    auditweights_source_PROMO
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# 5                        NaN
# 6                        NaN
# 7                        NaN
# 8                        NaN
# 9                        NaN
#
# [10 rows x 168 columns]

# %%
# Compute inverted predictions (to sort by later)
test["predictions"] = -model.predict_proba(test[[
        'auditweights_svd_prelaunch', 
        'auditweights_ctr_high', 
        'auditweights_ctr_gender', 
        'auditweights_friendLikes']].fillna(0.0).values)[:, 1]

# %%
# Peek only needed columns and sort
result = test[["instanceId_userId", "instanceId_objectId", "predictions"]].sort_values(
    by=['instanceId_userId', 'predictions'])
result.head(10)
# Out:
#          instanceId_userId  instanceId_objectId  predictions
# 337303                  39             35321415    -0.205321
# 337300                  39             18936317    -0.060567
# 337301                  39             38436621    -0.029520
# 337302                  39             38345738    -0.008043
# 1010995                 78             14594128    -0.249085
# 1010994                 78             38727626    -0.191624
# 1010993                 78               549335    -0.104174
# 676506                 135             17551814    -0.362909
# 676504                 135             17738426    -0.344983
# 676513                 135             18057011    -0.292308

# %%
# Collect predictions for each user
submit = result.groupby("instanceId_userId")['instanceId_objectId'].apply(list)
submit.head(10)
# Out:
# instanceId_userId
# 39               [35321415, 18936317, 38436621, 38345738]
# 78                           [14594128, 38727626, 549335]
# 135     [17551814, 17738426, 18057011, 34080312, 38102...
# 180                                  [35804715, 12537921]
# 231                [30371401, 34978207, 975302, 30978017]
# 279                                   [12179433, 9471943]
# 681                        [20314212, 35151632, 35119221]
# 873                                  [18419723, 15483310]
# 1071    [25539638, 23720423, 36006622, 25050009, 35834...
# 1113                       [35894718, 29841332, 15781817]
# Name: instanceId_objectId, dtype: object

# %%
# Persist the first submit
submit.to_csv(output_path + "/collabSubmit.csv.gz", header = False, compression='gzip')
